# %% [markdown]
# ## 제10장 초해상

# %% [markdown]
# ****공통 모듈 읽어들이기****

# %%
import os
import glob
import math
import random

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.python import keras
from tensorflow.python.keras import backend as K
from tensorflow.python.keras.models import Model, Sequential
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img
from tensorflow.python.keras.layers import Add, Input, Conv2D, Conv2DTranspose, Dense, Input, MaxPooling2D, UpSampling2D, Lambda

# %% [markdown]
# **예제 코드10.1:저해상도 이미지 생성**

# %%
def drop_resolution(x, scale=3.0):
    size = (x.shape[0], x.shape[1])
    small_size = (int(size[0]/scale), int(size[1]/scale))
    img = array_to_img(x)
    small_img = img.resize(small_size, 3)
    return img_to_array(small_img.resize(img.size, 3))

# %% [markdown]
# **예제 코드10.2:생성기 정의**

# %%
def data_generator(data_dir, mode, scale=2.0, target_size=(200, 200), batch_size=32, shuffle=True):
    for imgs in ImageDataGenerator().flow_from_directory(
        directory=data_dir,
        classes=[mode],
        class_mode=None,
        color_mode='rgb',
        target_size=target_size,
        batch_size=batch_size,
        shuffle=shuffle):
        
        x = np.array([drop_resolution(img, scale) for img in imgs])
        
        yield x/255., imgs/255.

# %% [markdown]
# **예제 코드10.3:data_generator의 이용**

# %%
DATA_DIR = 'data/chap10/'  # train, test folder
N_TRAIN_DATA = 1000
N_TEST_DATA = 100
BATCH_SIZE = 32

train_data_generator = data_generator(DATA_DIR, 'train', batch_size=BATCH_SIZE)

test_x, test_y = next(
    data_generator(
        DATA_DIR,
        'test',
        batch_size=N_TEST_DATA,
        shuffle=False
    )
)
# Out:
# Found 100 images belonging to 1 classes.

# %% [markdown]
# **예제 코드10.4:SRCNN의 정의**

# %%
model = Sequential()
model.add(Conv2D(filters=64, kernel_size=9, padding='same', activation='relu', input_shape=(None, None, 3)))
model.add(Conv2D(filters=32, kernel_size=1, padding='same', activation='relu'))
model.add(Conv2D(filters=3, kernel_size=5, padding='same'))

model.summary()
# Out:
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, None, None, 64)    15616
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, None, 32)    2080
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, None, 3)     2403
# =================================================================
# Total params: 20,099
# Trainable params: 20,099
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **예제 코드10.5:최대 신호 대 잡음비(PSNR, Peak signal to noise ratio)의 정의**

# %%
# metric으로 사용할 함수
def psnr(y_true, y_pred):
    return -10*K.log(
        K.mean(K.flatten((y_true - y_pred))**2)
    )/np.log(10)

# %% [markdown]
# **예제 코드10.6:PSNR을 metrics에 지정하고 학습을 실행**

# %%
model.compile(
    loss='mean_squared_error', 
    optimizer='adam', 
    metrics=[psnr]
)

model.fit_generator(
    train_data_generator,
    validation_data=(test_x, test_y),
    steps_per_epoch=N_TRAIN_DATA//BATCH_SIZE,
    epochs=20
)

# 테스트 데이터에 적용
pred = model.predict(test_x)
# Out:
# Found 800 images belonging to 1 classes.
# Epoch 1/20
# 31/31 [==============================] - 8s 245ms/step - loss: 0.0296 - psnr: 16.3214 - val_loss: 0.0156 - val_psnr: 18.2301
# Epoch 2/20
# 31/31 [==============================] - 5s 165ms/step - loss: 0.0103 - psnr: 19.9123 - val_loss: 0.0101 - val_psnr: 20.1761
# Epoch 3/20
# 31/31 [==============================] - 5s 161ms/step - loss: 0.0075 - psnr: 21.3091 - val_loss: 0.0082 - val_psnr: 21.1476
# Epoch 4/20
# 31/31 [==============================] - 5s 164ms/step - loss: 0.0062 - psnr: 22.1209 - val_loss: 0.0073 - val_psnr: 21.6758
# Epoch 5/20
# 31/31 [==============================] - 5s 162ms/step - loss: 0.0064 - psnr: 22.0002 - val_loss: 0.0069 - val_psnr: 21.9277
# Epoch 6/20
# 31/31 [==============================] - 5s 166ms/step - loss: 0.0056 - psnr: 22.5479 - val_loss: 0.0066 - val_psnr: 22.1214
# Epoch 7/20
# 31/31 [==============================] - 5s 163ms/step - loss: 0.0054 - psnr: 22.7457 - val_loss: 0.0064 - val_psnr: 22.3013
# Epoch 8/20
# 31/31 [==============================] - 5s 160ms/step - loss: 0.0050 - psnr: 23.0616 - val_loss: 0.0062 - val_psnr: 22.4568
# Epoch 9/20
# 31/31 [==============================] - 5s 160ms/step - loss: 0.0050 - psnr: 23.0526 - val_loss: 0.0063 - val_psnr: 22.3375
# Epoch 10/20
# 31/31 [==============================] - 5s 160ms/step - loss: 0.0047 - psnr: 23.3598 - val_loss: 0.0060 - val_psnr: 22.6037
# Epoch 11/20
# 31/31 [==============================] - 5s 161ms/step - loss: 0.0047 - psnr: 23.3061 - val_loss: 0.0057 - val_psnr: 22.8252
# Epoch 12/20
# 31/31 [==============================] - 5s 160ms/step - loss: 0.0045 - psnr: 23.4876 - val_loss: 0.0056 - val_psnr: 22.9248
# Epoch 13/20
# 31/31 [==============================] - 5s 160ms/step - loss: 0.0046 - psnr: 23.3876 - val_loss: 0.0055 - val_psnr: 22.9486
# Epoch 14/20
# 31/31 [==============================] - 5s 160ms/step - loss: 0.0044 - psnr: 23.5929 - val_loss: 0.0058 - val_psnr: 22.7381
# Epoch 15/20
# 31/31 [==============================] - 5s 161ms/step - loss: 0.0045 - psnr: 23.5510 - val_loss: 0.0055 - val_psnr: 23.0096
# Epoch 16/20
# 31/31 [==============================] - 5s 160ms/step - loss: 0.0044 - psnr: 23.6477 - val_loss: 0.0053 - val_psnr: 23.1460
# Epoch 17/20
# 31/31 [==============================] - 5s 160ms/step - loss: 0.0043 - psnr: 23.7630 - val_loss: 0.0053 - val_psnr: 23.1759
# Epoch 18/20
# 31/31 [==============================] - 5s 161ms/step - loss: 0.0042 - psnr: 23.8381 - val_loss: 0.0055 - val_psnr: 22.9371
# Epoch 19/20
# 31/31 [==============================] - 5s 161ms/step - loss: 0.0042 - psnr: 23.7716 - val_loss: 0.0052 - val_psnr: 23.2139
# Epoch 20/20
# 31/31 [==============================] - 5s 160ms/step - loss: 0.0043 - psnr: 23.7200 - val_loss: 0.0052 - val_psnr: 23.2652

# %% [markdown]
# **그림10.6:정답 데이터（실행환경에 따라 조금씩 다를 수 있습니다）**

# %%
array_to_img(test_y[0])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x1B3A138F630>

# %% [markdown]
# **그림10.7:입력데이터**

# %%
array_to_img(test_x[0])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x1B3A15D9780>

# %% [markdown]
# **그림10.8:예측결과**

# %%
array_to_img(pred[0])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x1B3A1565710>

# %% [markdown]
# ## CAE를 이용한 SRCNN

# %% [markdown]
# **예제 코드10.7:모델 구축 - CAE 구조에 skip connection 이용**

# %%
# 입력은 임의의 사이즈, 3 채널의 이미지
inputs = Input((None, None, 3), dtype='float')

# Endoder
conv1 = Conv2D(32, 3, padding='same')(inputs)
conv1 = Conv2D(32, 3, padding='same')(conv1)

conv2 = Conv2D(32, 3, strides=2, padding='same')(conv1)
conv2 = Conv2D(32, 3, padding='same')(conv2)

conv3 = Conv2D(32, 3, strides=2, padding='same')(conv2)
conv3 = Conv2D(32, 3, padding='same')(conv3)

# Decoder
deconv3 = Conv2DTranspose(32, 3, padding='same')(conv3)
deconv3 = Conv2DTranspose(32, 3, strides=2, padding='same')(deconv3)

# Add() 레이어를 사용해서 스킵 연결 구현
merge2 = Add()([deconv3, conv2])
deconv2 = Conv2DTranspose(32, 3, padding='same')(merge2)
deconv2 = Conv2DTranspose(32, 3, strides=2, padding='same')(deconv2)

merge1 = Add()([deconv2, conv1])
deconv1 = Conv2DTranspose(32, 3, padding='same')(merge1)
deconv1 = Conv2DTranspose(3, 3, padding='same')(deconv1)

output = Add()([deconv1, inputs])

model2 = Model(inputs, output)

# %% [markdown]
# **PSNR을metrics에 지정해서 학습 실행**

# %%
model2.compile(
    loss='mean_squared_error', 
    optimizer='adam', 
    metrics=[psnr]
)

model2.fit_generator(
    train_data_generator,
    validation_data=(test_x, test_y),
    steps_per_epoch=N_TRAIN_DATA//BATCH_SIZE,
    epochs=20
)

# 테스트 데이터로 적용
pred = model2.predict(test_x)
# Out:
# Epoch 1/20
# 31/31 [==============================] - 10s 319ms/step - loss: 0.0067 - psnr: 22.4913 - val_loss: 0.0052 - val_psnr: 23.2182
# Epoch 2/20
# 31/31 [==============================] - 7s 240ms/step - loss: 0.0040 - psnr: 23.9582 - val_loss: 0.0049 - val_psnr: 23.4964
# Epoch 3/20
# 31/31 [==============================] - 7s 241ms/step - loss: 0.0038 - psnr: 24.2055 - val_loss: 0.0048 - val_psnr: 23.5824
# Epoch 4/20
# 31/31 [==============================] - 7s 241ms/step - loss: 0.0037 - psnr: 24.3426 - val_loss: 0.0048 - val_psnr: 23.6263
# Epoch 5/20
# 31/31 [==============================] - 8s 244ms/step - loss: 0.0037 - psnr: 24.3499 - val_loss: 0.0048 - val_psnr: 23.6591
# Epoch 6/20
# 31/31 [==============================] - 8s 249ms/step - loss: 0.0039 - psnr: 24.1835 - val_loss: 0.0047 - val_psnr: 23.6776
# Epoch 7/20
# 31/31 [==============================] - 7s 241ms/step - loss: 0.0037 - psnr: 24.3760 - val_loss: 0.0047 - val_psnr: 23.6903
# Epoch 8/20
# 31/31 [==============================] - 7s 241ms/step - loss: 0.0036 - psnr: 24.4661 - val_loss: 0.0047 - val_psnr: 23.7081
# Epoch 9/20
# 31/31 [==============================] - 7s 241ms/step - loss: 0.0038 - psnr: 24.2706 - val_loss: 0.0047 - val_psnr: 23.7150
# Epoch 10/20
# 31/31 [==============================] - 8s 244ms/step - loss: 0.0036 - psnr: 24.4898 - val_loss: 0.0047 - val_psnr: 23.7254
# Epoch 11/20
# 31/31 [==============================] - 7s 241ms/step - loss: 0.0037 - psnr: 24.3449 - val_loss: 0.0047 - val_psnr: 23.7311
# Epoch 12/20
# 31/31 [==============================] - 8s 243ms/step - loss: 0.0036 - psnr: 24.4686 - val_loss: 0.0047 - val_psnr: 23.7351
# Epoch 13/20
# 31/31 [==============================] - 7s 241ms/step - loss: 0.0037 - psnr: 24.3549 - val_loss: 0.0047 - val_psnr: 23.7369
# Epoch 14/20
# 31/31 [==============================] - 8s 242ms/step - loss: 0.0037 - psnr: 24.3779 - val_loss: 0.0047 - val_psnr: 23.7404
# Epoch 15/20
# 31/31 [==============================] - 7s 242ms/step - loss: 0.0037 - psnr: 24.4019 - val_loss: 0.0047 - val_psnr: 23.7410
# Epoch 16/20
# 31/31 [==============================] - 7s 241ms/step - loss: 0.0037 - psnr: 24.4152 - val_loss: 0.0047 - val_psnr: 23.7428
# Epoch 17/20
# 31/31 [==============================] - 7s 241ms/step - loss: 0.0036 - psnr: 24.4898 - val_loss: 0.0047 - val_psnr: 23.7494
# Epoch 18/20
# 31/31 [==============================] - 7s 241ms/step - loss: 0.0036 - psnr: 24.4414 - val_loss: 0.0047 - val_psnr: 23.7491
# Epoch 19/20
# 31/31 [==============================] - 8s 243ms/step - loss: 0.0037 - psnr: 24.3397 - val_loss: 0.0047 - val_psnr: 23.7445
# Epoch 20/20
# 31/31 [==============================] - 8s 243ms/step - loss: 0.0037 - psnr: 24.3230 - val_loss: 0.0047 - val_psnr: 23.7500

# %% [markdown]
# **그림10.10:정답데이터**

# %%
array_to_img(test_y[0])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x1B3A1565438>

# %% [markdown]
# **그림10.11:입력데이터**

# %%
array_to_img(test_x[0])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x1B3A1565748>

# %% [markdown]
# **그림10.12:예측결과**

# %%
array_to_img(pred[0])
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x1B3BAC2CE80>
